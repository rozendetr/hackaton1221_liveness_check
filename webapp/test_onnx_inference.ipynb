# %%
import cv2
import os
from matplotlib import pyplot as plt
import numpy as np
import time
import yaml

from src.classificator import LivenessSpoof

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# %%
test_image = r"./screen2.jpg"
img = cv2.imread(test_image)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

visualize(img=img)

# %%
class_spoof = LivenessSpoof(weights=r"./2021-12-12-04-19_Anti_Spoofing_4_0_0_224x224_model_iter-12500.onnx",
                     input_res=(224,224),
                     batch_size=1)

# %%
img_input = class_spoof.preprocessing(img)

# %%
img_input[0].shape
# Out:
# (1, 3, 224, 224)

# %%
onnx_result = class_spoof(img)

# %%
onnx_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-56b0688e1cde> in <module>
# ----> 1 onnx_result
#
# NameError: name 'onnx_result' is not defined

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %%
print(softmax(onnx_result).argmax())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-67318da990cf> in <module>
# ----> 1 print(softmax(onnx_result).argmax())
#
# NameError: name 'softmax' is not defined

# %%
a = [1,2,3,7,8]
new_a = np.delete(a, 3)
new_a
# Out:
# array([1, 2, 3, 8])

# %%
import time

# %%
start_time = time.time()

# %%
time.time() - start_time
# Out:
# 0.16571402549743652

# %%
softmax(onnx_result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-77a170572320> in <module>
# ----> 1 softmax(onnx_result)
#
# NameError: name 'softmax' is not defined

# %%
x_tl, y_tl, x_br, y_br, class_id = [115, 92, 203, 214, 0]

# %%
w_bbox = x_br-x_tl
h_bbox = y_br-y_tl

# %%
rect = np.zeros((768,1024,3))
rect[:,:,0]=255

# %%
rect.shape
# Out:
# (768, 1024, 3)
